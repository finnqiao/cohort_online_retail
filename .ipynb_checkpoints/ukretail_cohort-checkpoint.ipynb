# %%
import pandas as pd
import seaborn as sb
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno

# %%
online_data = pd.read_excel('online_retail.xlsx')

# %%
online_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
len(online_data)
# Out:
# 541909

# %%
main_df = online_data[['Description','InvoiceDate','CustomerID','Country','Quantity','UnitPrice']]

# %%
main_df.columns = ['description','invoice_date','cust_id','country','quantity','unit_price']

# %%
main_df['tot_order'] = online_data['Quantity']*online_data['UnitPrice']
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
main_df.head()
# Out:
#                            description        invoice_date  cust_id  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00  17850.0
# 1                  WHITE METAL LANTERN 2010-12-01 08:26:00  17850.0
# 2       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00  17850.0
# 3  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00  17850.0
# 4       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00  17850.0
#
#           country  quantity  unit_price  tot_order
# 0  United Kingdom         6        2.55      15.30
# 1  United Kingdom         6        3.39      20.34
# 2  United Kingdom         8        2.75      22.00
# 3  United Kingdom         6        3.39      20.34
# 4  United Kingdom         6        3.39      20.34

# %%
msno.matrix(main_df)

# %%
# len(np.isnan(main_df['cust_id']))
main_df.loc[:, main_df.isna().any()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-c46d02f576d5> in <module>()
#       1 # len(np.isnan(main_df['cust_id']))
# ----> 2 main_df.loc[:, main_df.isna().any()]
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
refund_df = main_df[main_df['tot_order'] < 0]
refund_df.head()
# Out:
#                           description        invoice_date  cust_id  \
# 141                          Discount 2010-12-01 09:41:00  14527.0
# 154   SET OF 3 COLOURED  FLYING DUCKS 2010-12-01 09:49:00  15311.0
# 235    PLASTERS IN TIN CIRCUS PARADE  2010-12-01 10:24:00  17548.0
# 236  PACK OF 12 PINK PAISLEY TISSUES  2010-12-01 10:24:00  17548.0
# 237  PACK OF 12 BLUE PAISLEY TISSUES  2010-12-01 10:24:00  17548.0
#
#             country  quantity  unit_price  tot_order
# 141  United Kingdom        -1       27.50     -27.50
# 154  United Kingdom        -1        4.65      -4.65
# 235  United Kingdom       -12        1.65     -19.80
# 236  United Kingdom       -24        0.29      -6.96
# 237  United Kingdom       -24        0.29      -6.96

# %%
main_df[main_df['description'] == 'AMAZON FEE']
# np.isnan(main_df.loc[14514]['cust_id'])
# Out:
# True

# %%
# refund averages
refund_avg_price = refund_df.groupby('description')['unit_price'].mean()
refund_avg_price.sort_values(ascending = False)
# Out:
# description
# AMAZON FEE                              7352.549688
# Manual                                   575.172869
# CRUK Commission                          495.839375
# Bank Charges                             293.625600
# VINTAGE RED KITCHEN CABINET              185.062500
# RUSTIC  SEVENTEEN DRAWER SIDEBOARD       138.333333
# VINTAGE BLUE KITCHEN CABINET             133.333333
# LOVE SEAT ANTIQUE WHITE METAL            129.375000
# POSTAGE                                   90.446349
# Discount                                  72.484545
# SCHOOL DESK AND CHAIR                     65.000000
# DECORATIVE HANGING SHELVING UNIT          59.950000
# BROCADE RING PURSE                        57.600000
# SAMPLES                                   51.023607
# CINDERELLA CHANDELIER                     40.320000
# MEDINA STAMPED METAL STOOL                39.950000
# DANISH ROSE BEDSIDE CABINET               39.950000
# SET/4 WHITE RETRO STORAGE CUBES           37.450000
# 3 TIER SWEETHEART GARDEN SHELF            35.950000
# CARRIAGE                                  32.500000
# SILVER ROCCOCO CHANDELIER                 29.950000
# CABIN BAG VINTAGE RETROSPOT               25.650000
# RUSTIC WOODEN CABINET, GLASS DOORS        24.950000
# CHALKBOARD KITCHEN ORGANISER              23.450000
# BOTANICAL GARDENS WALL CLOCK              23.038462
# FRENCH STYLE EMBOSSED HEART CABINET       21.950000
# CHEST 7 DRAWER MA CAMPAGNE                21.950000
# CABIN BAG VINTAGE PAISLEY                 20.883333
# ROCOCO WALL MIRROR WHITE                  19.700000
# DOLLY GIRL BABY GIFT SET                  16.950000
#                                            ...
# PACK OF 12 PINK PAISLEY TISSUES            0.290000
# SET/4 BIRD MIRROR MAGNETS                  0.290000
# SUMMER FUN DESIGN SHOWER CAP               0.290000
# PSYCHEDELIC TILE COASTER                   0.290000
# PACK OF 12 BLUE PAISLEY TISSUES            0.290000
# STRIPY DESIGN SHOWER CAP                   0.290000
# WORLD WAR 2 GLIDERS ASSTD DESIGNS          0.238000
# RECYCLED PENCIL WITH RABBIT ERASER         0.210000
# DINOSAUR KEYRINGS ASSORTED                 0.210000
# SLEEPING CAT ERASERS                       0.210000
# BOYS ALPHABET IRON ON PATCHES              0.210000
# WHITE SAGE INCENSE                         0.210000
# ASSORTED CIRCULAR MOBILE                   0.210000
# PENS ASSORTED SPACEBALL                    0.190000
# ASSORTED TUTTI FRUTTI BRACELET             0.190000
# PENS ASSORTED FUNKY JEWELED                0.190000
# SET/6 FRUIT SALAD PAPER CUPS               0.190000
# DECORATION SITTING BUNNY                   0.190000
# STARS GIFT TAPE                            0.190000
# HEART DECORATION RUSTIC HANGING            0.190000
# SMALLFOLKART BAUBLE CHRISTMAS DEC          0.190000
# SET/6 COLLAGE PAPER CUPS                   0.190000
# GREETING CARD, STICKY GORDON               0.190000
# POPART RECT PENCIL SHARPENER ASST          0.120000
# HANGING WOOD AND FELT FLOWER               0.120000
# WINE BOTTLE DRESSING DARK BLUE             0.120000
# PAPER POCKET TRAVELING FAN                 0.105000
# PIECE OF CAMO STATIONERY SET               0.080000
# HOUSE SHAPE PENCIL SHARPENER               0.060000
# Adjust bad debt                       -11062.060000
# Name: unit_price, Length: 1973, dtype: float64

# %%
main_df = main_df[main_df['tot_order'] > 0]
main_df.head()
# Out:
#    cust_id                          description        invoice_date  \
# 0  17850.0   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00
# 1  17850.0                  WHITE METAL LANTERN 2010-12-01 08:26:00
# 2  17850.0       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00
# 3  17850.0  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00
# 4  17850.0       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00
#
#           country  quantity  unit_price  tot_order order_period cohort_group
# 0  United Kingdom         6        2.55      15.30      2010-12      2010-12
# 1  United Kingdom         6        3.39      20.34      2010-12      2010-12
# 2  United Kingdom         8        2.75      22.00      2010-12      2010-12
# 3  United Kingdom         6        3.39      20.34      2010-12      2010-12
# 4  United Kingdom         6        3.39      20.34      2010-12      2010-12

# %%
main_df['description'].value_counts().head()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2323
# JUMBO BAG RED RETROSPOT               2112
# REGENCY CAKESTAND 3 TIER              2017
# PARTY BUNTING                         1706
# LUNCH BAG RED RETROSPOT               1594
# Name: description, dtype: int64

# %%
main_df['country'].value_counts().head()
# Out:
# United Kingdom    485123
# Germany             9040
# France              8407
# EIRE                7890
# Spain               2484
# Name: country, dtype: int64

# %%
item_avg_price = main_df.groupby('description')['unit_price'].mean()
item_avg_price.sort_values(ascending = False)
# Out:
# description
# Adjust bad debt                        11062.060000
# AMAZON FEE                              6880.545000
# PICNIC BASKET WICKER 60 PIECES           649.500000
# DOTCOM POSTAGE                           292.137068
# Manual                                   230.151491
# RUSTIC  SEVENTEEN DRAWER SIDEBOARD       158.076923
# REGENCY MIRROR WITH SHUTTERS             156.428571
# VINTAGE BLUE KITCHEN CABINET             146.750000
# VINTAGE RED KITCHEN CABINET              143.421053
# CHEST NATURAL WOOD 20 DRAWERS            118.076923
# LOVE SEAT ANTIQUE WHITE METAL            114.024390
# Dotcomgiftshop Gift Voucher £100.00       83.330000
# VINTAGE POST OFFICE CABINET               66.360000
# SCHOOL DESK AND CHAIR                     63.915385
# DECORATIVE HANGING SHELVING UNIT          59.950000
# HALL CABINET WITH 3 DRAWERS               56.508000
# BLUE PAINTED KASHMIRI CHAIR               49.950000
# CARRIAGE                                  49.879433
# CINDERELLA CHANDELIER                     45.487391
# SET/4 WHITE RETRO STORAGE CUBES           45.232258
# PINK PAINTED KASHMIRI CHAIR               42.950000
# Dotcomgiftshop Gift Voucher £50.00        41.890000
# DANISH ROSE BEDSIDE CABINET               39.950000
# MEDINA STAMPED METAL STOOL                39.869500
# SILVER ROCCOCO CHANDELIER                 39.396667
# FUSCHIA RETRO BAR STOOL                   39.150000
# IVORY EMBROIDERED QUILT                   38.972903
# CHALKBOARD KITCHEN ORGANISER              37.610000
# 3 TIER SWEETHEART GARDEN SHELF            35.670930
# Dotcomgiftshop Gift Voucher £40.00        33.566667
#                                            ...
# ASSTD DESIGN BUBBLE GUM RING               0.210000
# RETRO PILL BOX , REVOLUTIONARY             0.208333
# WINE BOTTLE DRESSING LT.BLUE               0.205000
# ASSORTED INCENSE PACK                      0.202593
# ROUND PURPLE CLOCK WITH SUCKER             0.190000
# ROUND ARTICULATED PINK CLOCK W/SUCK        0.190000
# 3 BLACK CATS W HEARTS BLANK CARD           0.190000
# CHAMPAGNE TRAY BLANK CARD                  0.190000
# GREEN POP ART MAO CUSHION COVER            0.190000
# HAPPY BIRTHDAY CARD STRIPEY TEDDY          0.190000
# HAPPY BIRTHDAY CARD TEDDY/CAKE             0.190000
# CAT WITH SUNGLASSES BLANK CARD             0.190000
# GOLD PRINT PAPER BAG                       0.190000
# ASSORTED COLOUR SUCTION CUP HOOK           0.190000
# BLACK FEATHER CHRISTMAS DECORATION         0.190000
# ROUND BLUE CLOCK WITH SUCKER               0.190000
# FENG SHUI PILLAR CANDLE                    0.190000
# RETRO PILL BOX KEY CHAIN,THE KING          0.189286
# DISCO BALL CHRISTMAS DECORATION            0.163649
# LETTER SHAPE PENCIL SHARPENER              0.152444
# SMALL FOLDING SCISSOR(POINTED EDGE)        0.136143
# POPART RECT PENCIL SHARPENER ASST          0.129091
# MINI HIGHLIGHTER PENS                      0.120000
# POP ART PUSH DOWN RUBBER                   0.120000
# FOLDING CAMPING SCISSOR W/KNIF & S         0.120000
# WRAP BAD HAIR DAY                          0.100000
# BLUE STONES ON WIRE FOR CANDLE             0.099500
# PIECE OF CAMO STATIONERY SET               0.096774
# POPART WOODEN PENCILS ASST                 0.043478
# PADS TO MATCH ALL CUSHIONS                 0.001000
# Name: unit_price, Length: 4026, dtype: float64

# %%
time_df = main_df.set_index('invoice_date')

# %matplotlib inline
agg_df = pd.concat([time_df['unit_price'],time_df['tot_order'].rolling(30).mean()], axis = 1)
agg_df.plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
main_df['unit_price'].describe()
len(main_df[main_df['unit_price']>100])
# Out:
# 811

# %%
main_df['order_period'] = main_df['invoice_date'].apply(lambda x: x.strftime('%Y-%m'))
main_df.head()
# Out:
#                            description        invoice_date  cust_id  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00  17850.0
# 1                  WHITE METAL LANTERN 2010-12-01 08:26:00  17850.0
# 2       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00  17850.0
# 3  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00  17850.0
# 4       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00  17850.0
#
#           country  quantity  unit_price  tot_order order_period
# 0  United Kingdom         6        2.55      15.30      2010-12
# 1  United Kingdom         6        3.39      20.34      2010-12
# 2  United Kingdom         8        2.75      22.00      2010-12
# 3  United Kingdom         6        3.39      20.34      2010-12
# 4  United Kingdom         6        3.39      20.34      2010-12

# %%
main_df.set_index('cust_id', inplace = True)
main_df.head()
# Out:
#                                  description        invoice_date  \
# cust_id
# 17850.0   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00
# 17850.0                  WHITE METAL LANTERN 2010-12-01 08:26:00
# 17850.0       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00
# 17850.0  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00
# 17850.0       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00
#
#                 country  quantity  unit_price  tot_order order_period
# cust_id
# 17850.0  United Kingdom         6        2.55      15.30      2010-12
# 17850.0  United Kingdom         6        3.39      20.34      2010-12
# 17850.0  United Kingdom         8        2.75      22.00      2010-12
# 17850.0  United Kingdom         6        3.39      20.34      2010-12
# 17850.0  United Kingdom         6        3.39      20.34      2010-12

# %%
main_df['cohort_group'] = main_df.groupby(level=0)['invoice_date'].min().apply(lambda x: x.strftime('%Y-%m'))
main_df.head()
# Out:
#                                  description        invoice_date  \
# cust_id
# 17850.0   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00
# 17850.0                  WHITE METAL LANTERN 2010-12-01 08:26:00
# 17850.0       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00
# 17850.0  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00
# 17850.0       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00
#
#                 country  quantity  unit_price  tot_order order_period  \
# cust_id
# 17850.0  United Kingdom         6        2.55      15.30      2010-12
# 17850.0  United Kingdom         6        3.39      20.34      2010-12
# 17850.0  United Kingdom         8        2.75      22.00      2010-12
# 17850.0  United Kingdom         6        3.39      20.34      2010-12
# 17850.0  United Kingdom         6        3.39      20.34      2010-12
#
#         cohort_group
# cust_id
# 17850.0      2010-12
# 17850.0      2010-12
# 17850.0      2010-12
# 17850.0      2010-12
# 17850.0      2010-12

# %%
main_df.reset_index(inplace = True)
main_df.head()
# Out:
#    cust_id                          description        invoice_date  \
# 0  17850.0   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00
# 1  17850.0                  WHITE METAL LANTERN 2010-12-01 08:26:00
# 2  17850.0       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00
# 3  17850.0  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00
# 4  17850.0       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00
#
#           country  quantity  unit_price  tot_order order_period cohort_group
# 0  United Kingdom         6        2.55      15.30      2010-12      2010-12
# 1  United Kingdom         6        3.39      20.34      2010-12      2010-12
# 2  United Kingdom         8        2.75      22.00      2010-12      2010-12
# 3  United Kingdom         6        3.39      20.34      2010-12      2010-12
# 4  United Kingdom         6        3.39      20.34      2010-12      2010-12

# %%
grouped = main_df.groupby(['cohort_group','order_period'])
cohorts = grouped.agg({'cust_id': pd.Series.nunique,
                       'description': pd.Series.nunique,
                      'quantity': np.sum,
                      'tot_order': np.sum})
cohorts.rename(columns ={'cust_id':'total_customers',
                         'description':'total_product_types',
                        'quantity':'total_units'}, inplace = True)
cohorts.head()
# Out:
#                            total_customers  total_product_types  total_units  \
# cohort_group order_period
# 2010-12      2010-12                 948.0                 2429       296362
#              2011-01                 362.0                 1835       158898
#              2011-02                 317.0                 1721       137581
#              2011-03                 367.0                 1870       179256
#              2011-04                 341.0                 1794       130621
#
#                            tot_order
# cohort_group order_period
# 2010-12      2010-12       554604.02
#              2011-01       271616.52
#              2011-02       230856.22
#              2011-03       302509.39
#              2011-04       200927.98
